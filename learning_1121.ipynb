# %%
import requests
url = 'https://czbooks.net/n/cpg7j6m'
# 假的headers 資訊
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'}
# 加入headers 資訊
web = requests.get(url, headers=headers)
web.encoding = 'utf8'
print(web.text)
# Out:
# <!doctype html>
# <html>
#     <head>
#         <!-- meta -->
# 		<title>【免費小說】《C語言修仙》2024最新連載、線上看 | 小說狂人</title>
# 		<meta name="Robots" content="index, follow">
# 		<meta charset="UTF-8"/>
# 		<meta name="viewport" content="width=device-width">
# 		<meta name="title" content="【免費小說】《C語言修仙》2024最新連載、線上看 | 小說狂人">
# 		<meta name="keywords" content="">
# 		<meta name="description" content="一十四洲+番外＞,小說,線上看,txt,下載,手機,電腦,簡體,繁體,完本,Dcard,台灣,大陸,限,全本小說網,起點小說,卡提諾小說,ck101,黃金屋,PTT">
# 		<link href="/favicon.ico" rel="SHORTCUT ICON">
#
# 		<!-- google plus meta -->
# 		<meta itemprop="name" content='【免費小說】《C語言修仙》2024最新連載、線上看 | 小說狂人'>
# 		<meta itemprop="image" content="">
# 		<meta itemprop="description" content="一十四洲+番外＞,小說,線上看,txt,下載,手機,電腦,簡體,繁體,完本,Dcard,台灣,大陸,限,全本小說網,起點小說,卡提諾小說,ck101,黃金屋,PTT">
#
# 		<!-- facebook meta -->
# 		<meta property="og:title" content="【免費小說】《C語言修仙》2024最新連載、線上看 | 小說狂人"/>
# ...

# %%
import requests
web = requests.get('https://water.taiwanstat.com/')    # 使用 get 方法
web.encoding='utf-8'
# 因為該網頁編碼為utf-8，加上.encoding 避免亂碼
print(web.text)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="zh-TW"><head><meta property="og:title" content="台灣水庫即時水情"><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta property="og:site_name" content="台灣水庫即時水情"><meta property="og:description" content="台灣水庫即時水情-視覺化, 即時蓄水量、水位變化..."><meta property="og:image" content="http://i.imgur.com/04AFcnA.png"><meta property="og:image:type" content="image/png"><meta name="author" content="Chi-Hsuan Huang"><meta name="citation_authors" content="Po-An Yang"><meta name="description" content="台灣水庫即時水情-視覺化, 即時蓄水量、水位變化"><title>台灣水庫即時水情</title><meta property="og:locale" content="zh_TW"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" type="image/png" href="//static.taiwanstat.com/favicon.ico"><link rel="shortcut icon" href="//static.taiwanstat.com/favicon.ico" type="image/x-icon"><link rel="stylesheet" href="//static.taiwanstat.com/css/style.min.css"><link rel="stylesheet" href="//storage.googl
# ...

# %%
import csv
web = requests.get('https://data.kcg.gov.tw/dataset/6f29f6f4-2549-4473-aa90-bf60d10895dc/resource/30dfc2cf-17b5-4a40-8bb7c511ea166bd3/download/lightrailtraffic.csv')
web.encoding='utf-8'

# %%
data = json.loads(web.content.decode('utf-8-sig'))
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-15-712807519f6a> in <cell line: 1>()
# ----> 1 data = json.loads(web.content.decode('utf-8-sig'))
#       2 print(data)
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
from bs4 import BeautifulSoup
url = 'https://water.taiwanstat.com/'
web = requests.get(url)
#soup = BeautifulSoup(web.text, "html.parser")  # 使用
soup = BeautifulSoup(web.text, "html5lib")
title = soup.title
print(title)
# Out:
# <title>台灣水庫即時水情</title>

# %%
import requests as rq
#we need to request a web sitehttps://tw.sports.yahoo.com/news/12%E5%BC%B7%E3%80%8B%E4%B8%AD%E8%8F%AF%E9%9A%8A%E9%81%AD%E5%A7%94%E5%85%A7%E7%91%9E%E6%8B%89%E5%AE%8C%E5%B0%81-%E6%9B%BE%E7%B8%BD%EF%BC%9A%E3%80%8C%E8%B2%AC%E4%BB%BB%E5%9C%A8%E6%88%91%E3%80%8D-065355974.html'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'}
response = rq.get(url, headers = headers, timeout=2)
html = response.content
#print(html)
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup = BeautifulSoup(html, "html.parser")
for script in soup(["script", "style"]):
  script.extract()
 # get text
  text = soup.get_text()
 # create a new bs4 object from the html data loaded
 # remove all javascript and stylesheet code
 # break into lines and remove leading and trailing space on each
  lines = (line.strip() for line in text.splitlines())
 # break multi-headlines into a line each
  chunks = (phrase.strip() for line in lines for phrase in line.split(" "))
 # drop blank lines
  texts = '\n'.join(chunk for chunk in chunks if chunk)
print(texts)
# Out:
# Yahoo奇摩搜尋登入登入以檢視信箱熱搜：謝宜容娘家棒球12強蔡淑臻認愛36歲釋小龍短租公寓統一發票7
# 8月輝達財報首爾機票台中逢甲住宿英雄聯盟2354鴻準賈永婕連道歉12次黑浮咖啡賈永婕黃金價格廣告新聞股市理財運動名人娛樂電影戲劇Yahoo
# TV遊戲日本代購字典3C科技信箱搜尋氣象ATM公益商家指南拍賣購物中心時時樂汽車機車中古車保險時尚美妝房地產旅遊健康APP下載網路開店買廣告網路行銷聯名卡帳號保護訂餐廳關注挨委內瑞拉長打重擊
# 中華隊0比2遭完封輸掉複賽首戰焦點12強娛樂財經生活FUN手感火熱⋯陳傑憲被抽查藥檢自行印鈔92萬
# 夜市消費被抓包醬油廠曬全家福：不認識謝宜容中華隊遭完封⋯惜敗委內瑞拉12強複賽首戰，4局下挨了Carlos
# Pérez長打重擊，最終吞敗曾豪駒感歎「輸球責任在我」中華隊被委內瑞拉完封，他表示整體攻擊過程少了串聯度公務員之死
# 總統道歉
# 勞長請辭北分署長謝宜容遭記兩大過、免職，首度發表公開聲明致歉台積未來設廠規畫
# 3縣市被點名董事之一的國發會主委劉鏡清透露，高雄、台南、台中都有謝宜容請律師發12聲明
# 駁報導指稱部分事態發展已偏頗、悖離事實，形成公審效應「死在5步前」陳傑憲喊懊惱曾頌恩疑打到螢幕
# 笑稱怕被罵預賽評台灣弱隊
# 日媒態度大改江坤宇：羅戈這場非常難突破賽後表示狀況蠻好的，直球、曲球跟變速，都投得很有威力惜敗委內瑞拉
# 中華隊主帥攬責「教練這邊如果當下快點做應變，可能結果就會不一樣」滿壘錯失機會
# 中華隊慘遭完封全場多次上壘，但最終都無功而返，複賽首戰以0比2吞敗陳傑憲獲盛讚「MLB級天賦」他回應說「未來還是在中職，若年輕一點絕對以大聯盟為目標」韓國慘敗
# 老將歎：要追趕台灣對象不是日本！表示再這樣下去，2026WBC將重演更大的災難納豆求婚緊張到出包
# 依依笑了沒搭到飛機⋯今晚開唱突取消冰島泡湯有女伴？​修杰楷坦蕩蕩演《紅樓夢》成名
# 鄭錚離世享壽61歲，丈夫表示她因病經多方醫治無效，在北京與世長辭林政勳曾在馬路大喊
# 路人報警入圍金馬獎最佳新人，被要求每天去公園找人聊天凸肚不是懷孕
# 謝京穎取33顆卵與張書偉結婚一年，公開先前打排卵針後的照片被控爆料大根當爸
# 小優首發聲稱被誤會是大嘴巴，無端捲入風波，感歎「水逆到不行」一年沒公開露面
# ...

# %%
import requests
web = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html')
print(web.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# <script>
# (() => {
#     if (document.cookie.indexOf('over18=1') === -1) {
# 	location = 'https://www.ptt.cc/ask/over18?from=' + encodeURIComponent(location.pathname);
#     }
# })();
# </script>
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# ...

# %%
url = 'https://www.ptt.cc/'
web = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', cookies={'over18':'1'})
soup = BeautifulSoup(web.text, "html.parser")
titles = soup.find_all('div', class_='title')
for i in titles:
 if i.find('a') != None:
  print(i.find('a').get_text())
# 取得class 為title
# 判斷如果不為None
  # 取得 div 裡 a 的內容，
  print(url + i.find('a')['href'], end='\n\n')  # 使用 ['href'] 取得href 的屬性
# Out:
# Re: [爆卦] 俄羅斯向烏克蘭發射洲際彈道飛彈（ICBM）
# https://www.ptt.cc//bbs/Gossiping/M.1732178993.A.28A.html
#
# [問卦] 政府是不是維持最基本功能就好
# https://www.ptt.cc//bbs/Gossiping/M.1732179008.A.E96.html
#
# [問卦] 洲際彈道飛彈 飛到太空中 還需要警報嗎?
# https://www.ptt.cc//bbs/Gossiping/M.1732179062.A.6D9.html
#
# [問卦] 內雙的人是不是有時候會變外雙
# https://www.ptt.cc//bbs/Gossiping/M.1732179084.A.B21.html
#
# Re: [問卦] 數發部弄這衝三小？
# https://www.ptt.cc//bbs/Gossiping/M.1732179103.A.65B.html
#
# [問卦] 台積一堆謝等級的主管真的假的？
# https://www.ptt.cc//bbs/Gossiping/M.1732179161.A.D72.html
#
# 謝遺容的年薪
# https://www.ptt.cc//bbs/Gossiping/M.1732179329.A.37D.html
#
# [問卦] 文組想問 AI伺服器 跟楓之谷伺服器一樣嗎？
# https://www.ptt.cc//bbs/Gossiping/M.1732179355.A.E74.html
#
# [問卦] 如果用海參崴換基輔 值得嗎
# https://www.ptt.cc//bbs/Gossiping/M.1732179400.A.CCD.html
#
# [問卦] 謝宜容跟虐死凱凱保母 長相有像嗎
# https://www.ptt.cc//bbs/Gossiping/M.1732179430.A.A44.html
#
# [問卦] 烏克蘭會被種香菇嗎？
# https://www.ptt.cc//bbs/Gossiping/M.1732179447.A.4A8.html
#
# [問卦] 現實中  你敢惹宜容嗎？  就問一句
# ...

# %%
web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1732152792.A.D29.html', cookies={'over18':'1'}) # 傳送 Cookies 資訊後，抓取頁面內容
soup = BeautifulSoup(web.text, "html.parser") # 使用BeautifulSoup 取得網頁結構
imgs = soup.find_all('img') # 取得所有 img tag 的內容
for i in imgs:
 print(i['src'])
# Out:
# https://pbs.twimg.com/media/GbD-OhkbQAUOmnx.jpg
# https://pbs.twimg.com/media/GXrHbAvawAAUyeT.jpg
# https://pbs.twimg.com/media/GUduKx1W0AAUO0G.jpg
# https://pbs.twimg.com/media/GYfIx6rbEAAF4cm.jpg
# https://pbs.twimg.com/media/GbNmoaLbkAAOKme.jpg
# https://pbs.twimg.com/media/GaCpPttb0AAdF2I.jpg
# https://cache.ptt.cc/c/https/i.imgur.com/s3VOddil.gif?e=1732340691&s=42au_g-Ed3BAAoxHtFfFAw

# %%
import os
from google.colab import drive
# 挂载Google Drive（可选，如果需要保存到云端硬盘）
drive.mount('/content/drive')
# 定义并创建保存图片的目录
save_dir = '/content/drive/MyDrive/ Notebooks/download/'
if not os.path.exists(save_dir):
 os.makedirs(save_dir)
web = requests.get('https://www.ptt.cc/bbs/Beauty/M.1732152792.A.D29.html', cookies={'over18':'1'})
soup = BeautifulSoup(web.text, "html.parser")
imgs = soup.find_all('img')
name = 0    # 设定图片编号
for i in imgs:
 print(i['src'])
 jpg = requests.get(i['src'])  # 使用 requests 获取图片内容
 with open(f'{save_dir}test_{name}.jpg', 'wb') as f:
  f.write(jpg.content)  # 写入图片内容
 name += 1  # 编号增加1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# https://pbs.twimg.com/media/GbD-OhkbQAUOmnx.jpg
# https://pbs.twimg.com/media/GXrHbAvawAAUyeT.jpg
# https://pbs.twimg.com/media/GUduKx1W0AAUO0G.jpg
# https://pbs.twimg.com/media/GYfIx6rbEAAF4cm.jpg
# https://pbs.twimg.com/media/GbNmoaLbkAAOKme.jpg
# https://pbs.twimg.com/media/GaCpPttb0AAdF2I.jpg
# https://cache.ptt.cc/c/https/i.imgur.com/s3VOddil.gif?e=1732340691&s=42au_g-Ed3BAAoxHtFfFAw

# %%
import requests
url = 'https://invoice.etax.nat.gov.tw/index.html'
web = requests.get(url) # 取得網頁內容
web.encoding='utf-8'
print(web.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head>
#
#     <!-- Google Analytics -->
#     <!-- Google tag (gtag.js) -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-1RL7V80ELX"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-1RL7V80ELX');
#     </script>
#
#   <meta charset="UTF-8" />
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#   <meta name="format-detection" content="telephone=no" />
#   <meta name="viewport" content="width=device-width,initial-scale=1, user-scalable=no" />
#   <title>財政部稅務入口網</title>
#   <link rel="shortcut icon" type="image/x-icon" href="images/favicon.ico">
#   <!-- CSS_JS -->
#   <link rel="stylesheet" href="css/bootstrap.css">
#   <!-- CSS -->
#   <link rel="stylesheet" href="css/global.css">
#   <link rel="stylesheet" href="css/inner.css">
#   <!-- JS -->
# ...

# %%
soup = BeautifulSoup(web.text, "html.parser")
td = soup.select('.container-fluid')[0].select('.etw-tbiggest')  # 取出中獎號碼的位置
ns = td[0].getText()  # 特別獎
n1 = td[1].getText()  # 特獎
# 頭獎，因為存入串列會出現/n 換行符，使用[-8:] 取出最後八碼
n2 = [td[2].getText()[-8:], td[3].getText()[-8:], td[4].getText()[-8:]]
print(ns)
print(n1)
print(n2)
# Out:
# 38039158
# 08276859
# ['32110911', '84289408', '13446901']

# %%
url = 'https://rate.bot.com.tw/xrt/flcsv/0/day'   # 牌告匯率 CSV 網址
rate = requests.get(url)   # 爬取網址內容
rate.encoding = 'utf-8'    # 調整回應訊息編碼為 utf-8，避免編碼不同造成亂碼
rt = rate.text
rts = rt.split('\n')
for i in rts:
 try:
  a = i.split(',')
  # 以文字模式讀取內容
    # 使用「換行」將內容拆分成串列
    # 讀取串列的每個項目
  # 使用try 避開最後一行的空白行
    # 每個項目用逗號拆分成子串列
  print(a[0] + ': ' + a[12])   # 取出第一個 ( 0 ) 和第十三個項目 ( 12 )
 except:
  break
# Out:
# ﻿幣別: 現金
# USD: 32.81500
# HKD: 4.23000
# GBP: 42.03000
# AUD: 21.58000
# CAD: 23.71000
# SGD: 24.56000
# CHF: 37.24000
# JPY: 0.21470
# ZAR: 0.00000
# SEK: 0.00000
# NZD: 19.45000
# THB: 1.00190
# PHP: 0.61740
# IDR: 0.00238
# EUR: 34.78000
# KRW: 0.02540
# VND: 0.00145
# MYR: 7.79100
# CNY: 4.55900

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.image as img
import os
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats

# %%
# prompt: 讀取csv檔的程式

import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
file_path = 'annual-enterprise-survey-2023-financial-year-provisional-size-bands.csv'

try:
  # Read the CSV file into a pandas DataFrame
  df = pd.read_csv(file_path)

  # Now you can work with the data in the DataFrame 'df'
  print(df)  # Print the first few rows of the DataFrame

except FileNotFoundError:
  print(f"Error: File '{file_path}' not found.")
except pd.errors.ParserError:
  print(f"Error: Could not parse the CSV file '{file_path}'. Please check its format.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 20119  2023                  all                     All Industries
# 20120  2023                  all                     All Industries
# 20121  2023                  all                     All Industries
# 20122  2023                  all                     All Industries
# 20123  2023                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...
