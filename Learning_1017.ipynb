# %% [markdown]
# 前置作業 import pandas 跟 numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 讀取檔案

# %%
df=pd.read_csv('A_stat_data_112.csv')

# %% [markdown]
# 複製一份資料到df2(備份)
# 查看一些資料

# %%
df2=df.copy()
df2.head()
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                  112.0            112-2
# 1           連續                  112.0            112-2
# 2           連續                  112.0            112-2
# 3          非連續                  112.0            112-2
# 4        連續＋圖表                  112.0            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 2  Thu May 09 08:00:00 UTC 2024          已派發任務           0.0  ...
# 3  Mon May 13 08:00:00 UTC 2024          已派發任務           0.0  ...
# 4  Thu May 16 08:00:00 UTC 2024          已派發任務           0.0  ...
#
#   answer_duration_sec  mission_answer_count  content_indicator_correct_rate  \
# 0                 NaN                   0.0                             NaN
# 1                 NaN                   0.0                             NaN
# 2                 NaN                   0.0                             NaN
# 3                 NaN                   0.0                             NaN
# 4                 NaN                   0.0                             NaN
#
#    comprehensive_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    first_correct_rate       user_id    mission_id
# 0                 NaN -8.373966e+18  8.154604e+18
# 1                 NaN  3.516684e+18  3.762301e+18
# 2                 NaN -6.579905e+16  4.652808e+18
# 3                 NaN -6.293485e+18  2.406214e+17
# 4                 NaN  4.998280e+18 -3.340858e+18
#
# [5 rows x 22 columns]

# %%
df2.tail()
# Out:
#          grade                          mission_name mission_difficulty  \
# 1619385      4  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619386      5             04/25 扭蛋【多元文化教育－日本文化】（初階）                  中
# 1619387      5  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619388      5  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619389      5                                04/25                 NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 1619385            文化           連續                  112.0            112-2
# 1619386          世界櫥窗           連續                  112.0            112-2
# 1619387            文化           連續                  112.0            112-2
# 1619388            文化           連續                  112.0            112-2
# 1619389           NaN          NaN                    NaN              NaN
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 1619385  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619386  Thu Apr 25 08:00:00 UTC 2024           完成任務           1.0  ...
# 1619387  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619388  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619389                           NaN            NaN           NaN  ...
#
#         answer_duration_sec  mission_answer_count  \
# 1619385                 NaN                   0.0
# 1619386                24.0                   1.0
# 1619387                 NaN                   0.0
# 1619388                 NaN                   0.0
# 1619389                 NaN                   NaN
#
#          content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 1619385                             NaN                                   NaN
# 1619386                             NaN                                   1.0
# 1619387                             NaN                                   NaN
# 1619388                             NaN                                   NaN
# 1619389                             NaN                                   NaN
#
#          explanation_indicator_correct_rate  \
# 1619385                                 NaN
# 1619386                                 1.0
# 1619387                                 NaN
# 1619388                                 NaN
# 1619389                                 NaN
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 1619385                                NaN                          NaN
# 1619386                                1.0                          NaN
# 1619387                                NaN                          NaN
# 1619388                                NaN                          NaN
# 1619389                                NaN                          NaN
#
#          first_correct_rate       user_id    mission_id
# 1619385                 NaN -7.530624e+18  1.877827e+18
# 1619386                 1.0  6.601996e+18  2.576055e+18
# 1619387                 NaN -3.990416e+17  1.877827e+18
# 1619388                 NaN -6.914625e+18  1.877827e+18
# 1619389                 NaN           NaN           NaN
#
# [5 rows x 22 columns]

# %%
df.head()
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                  112.0            112-2
# 1           連續                  112.0            112-2
# 2           連續                  112.0            112-2
# 3          非連續                  112.0            112-2
# 4        連續＋圖表                  112.0            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 2  Thu May 09 08:00:00 UTC 2024          已派發任務           0.0  ...
# 3  Mon May 13 08:00:00 UTC 2024          已派發任務           0.0  ...
# 4  Thu May 16 08:00:00 UTC 2024          已派發任務           0.0  ...
#
#   answer_duration_sec  mission_answer_count  content_indicator_correct_rate  \
# 0                 NaN                   0.0                             NaN
# 1                 NaN                   0.0                             NaN
# 2                 NaN                   0.0                             NaN
# 3                 NaN                   0.0                             NaN
# 4                 NaN                   0.0                             NaN
#
#    comprehensive_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    first_correct_rate       user_id    mission_id
# 0                 NaN -8.373966e+18  8.154604e+18
# 1                 NaN  3.516684e+18  3.762301e+18
# 2                 NaN -6.579905e+16  4.652808e+18
# 3                 NaN -6.293485e+18  2.406214e+17
# 4                 NaN  4.998280e+18 -3.340858e+18
#
# [5 rows x 22 columns]

# %%
df.tail(3)
# Out:
#          grade                   mission_name mission_difficulty  \
# 1909956      8  04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909957      8           4月特別任務－【SDGs 議題】（中階）                NaN
# 1909958      9           4月特別任務－【SDGs 議題】（中階）                NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 1909956            議題          非連續                    112            112-2
# 1909957           NaN          NaN                    112            112-2
# 1909958           NaN          NaN                    112            112-2
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 1909956  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909957  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909958  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
#
#         answer_duration_sec  mission_answer_count  \
# 1909956                 NaN                     0
# 1909957                 NaN                     0
# 1909958                 NaN                     0
#
#          content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 1909956                             NaN                                   NaN
# 1909957                             NaN                                   NaN
# 1909958                             NaN                                   NaN
#
#          explanation_indicator_correct_rate  \
# 1909956                                 NaN
# 1909957                                 NaN
# 1909958                                 NaN
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 1909956                                NaN                          NaN
# 1909957                                NaN                          NaN
# 1909958                                NaN                          NaN
#
#          first_correct_rate              user_id          mission_id
# 1909956                 NaN -3633088233029289359  703618323232836566
# 1909957                 NaN -3198336096824660439 -371611706378504607
# 1909958                 NaN  8248998181802054321 -371611706378504607
#
# [3 rows x 22 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1619390, step=1)

# %%
df.columns
# Out:
# Index(['grade', 'mission_name', 'mission_difficulty', 'mission_field',
#        'mission_type', 'mission_semester_year', 'mission_semester',
#        'mission_datetime_utc8', 'mission_status', 'is_completed',
#        'completed_at_utc8', 'correct_rate', 'answer_duration_sec',
#        'mission_answer_count', 'content_indicator_correct_rate',
#        'comprehensive_indicator_correct_rate',
#        'explanation_indicator_correct_rate',
#        'extraction_indicator_correct_rate', 'form_indicator_correct_rate',
#        'first_correct_rate', 'user_id', 'mission_id'],
#       dtype='object')

# %% [markdown]
# 輸出資料欄位

# %%
a=df2.columns
a_series=a.to_series()
print(a_series)
a_series.to_csv('work1.csv',index=False)
# Out:
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# mission_semester_year                                  mission_semester_year
# mission_semester                                            mission_semester
# mission_datetime_utc8                                  mission_datetime_utc8
# mission_status                                                mission_status
# is_completed                                                    is_completed
# completed_at_utc8                                          completed_at_utc8
# correct_rate                                                    correct_rate
# answer_duration_sec                                      answer_duration_sec
# mission_answer_count                                    mission_answer_count
# content_indicator_correct_rate                content_indicator_correct_rate
# comprehensive_indicator_correct_rate    comprehensive_indicator_correct_rate
# explanation_indicator_correct_rate        explanation_indicator_correct_rate
# extraction_indicator_correct_rate          extraction_indicator_correct_rate
# form_indicator_correct_rate                      form_indicator_correct_rate
# first_correct_rate                                        first_correct_rate
# user_id                                                              user_id
# mission_id                                                        mission_id
# dtype: object

# %%
df.describe()
# Out:
#               grade  mission_semester_year  is_completed   correct_rate  \
# count  1.619390e+06              1619389.0  1.619389e+06  396821.000000
# mean   5.873797e+00                  112.0  2.450437e-01       0.412099
# std    1.566896e+00                    0.0  4.301132e-01       0.318293
# min    4.000000e+00                  112.0  0.000000e+00       0.000000
# 25%    5.000000e+00                  112.0  0.000000e+00       0.200000
# 50%    6.000000e+00                  112.0  0.000000e+00       0.400000
# 75%    7.000000e+00                  112.0  0.000000e+00       0.600000
# max    9.000000e+00                  112.0  1.000000e+00       1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count        395704.000000          1.619389e+06
# mean            147.707921          7.331166e-01
# std             330.354624          1.699804e+00
# min               1.000000          0.000000e+00
# 25%              10.000000          0.000000e+00
# 50%              37.000000          0.000000e+00
# 75%             176.000000          1.000000e+00
# max            3600.000000          2.100000e+02
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                    91417.000000                         391656.000000
# mean                         0.377835                              0.414392
# std                          0.475603                              0.402183
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              1.000000
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                       342726.000000                      361565.000000
# mean                             0.385136                           0.438467
# std                              0.446253                           0.454935
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.333333
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                 69412.000000       412816.000000  1.619389e+06
# mean                      0.375209            0.451908 -8.542953e+15
# std                       0.481996            0.316558  5.342546e+18
# min                       0.000000            0.000000 -9.223321e+18
# 25%                       0.000000            0.200000 -4.630740e+18
# 50%                       0.000000            0.400000  6.201597e+16
# 75%                       1.000000            0.600000  4.565156e+18
# max                       1.000000            1.000000  9.218903e+18
#
#          mission_id
# count  1.619389e+06
# mean  -1.240421e+17
# std    5.286050e+18
# min   -9.144214e+18
# 25%   -4.724245e+18
# 50%   -2.274875e+17
# 75%    3.909487e+18
# max    9.217426e+18

# %%
b=df2.describe()
print(b)
b.to_excel('work2.xlsx')
# Out:
#               grade  mission_semester_year  is_completed   correct_rate  \
# count  1.619390e+06              1619389.0  1.619389e+06  396821.000000
# mean   5.873797e+00                  112.0  2.450437e-01       0.412099
# std    1.566896e+00                    0.0  4.301132e-01       0.318293
# min    4.000000e+00                  112.0  0.000000e+00       0.000000
# 25%    5.000000e+00                  112.0  0.000000e+00       0.200000
# 50%    6.000000e+00                  112.0  0.000000e+00       0.400000
# 75%    7.000000e+00                  112.0  0.000000e+00       0.600000
# max    9.000000e+00                  112.0  1.000000e+00       1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count        395704.000000          1.619389e+06
# mean            147.707921          7.331166e-01
# std             330.354624          1.699804e+00
# min               1.000000          0.000000e+00
# 25%              10.000000          0.000000e+00
# 50%              37.000000          0.000000e+00
# 75%             176.000000          1.000000e+00
# max            3600.000000          2.100000e+02
#
#        content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# count                    91417.000000                         391656.000000
# mean                         0.377835                              0.414392
# std                          0.475603                              0.402183
# min                          0.000000                              0.000000
# 25%                          0.000000                              0.000000
# 50%                          0.000000                              0.333333
# 75%                          1.000000                              1.000000
# max                          1.000000                              1.000000
#
#        explanation_indicator_correct_rate  extraction_indicator_correct_rate  \
# count                       342726.000000                      361565.000000
# mean                             0.385136                           0.438467
# std                              0.446253                           0.454935
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.333333
# 75%                              1.000000                           1.000000
# max                              1.000000                           1.000000
#
#        form_indicator_correct_rate  first_correct_rate       user_id  \
# count                 69412.000000       412816.000000  1.619389e+06
# mean                      0.375209            0.451908 -8.542953e+15
# std                       0.481996            0.316558  5.342546e+18
# min                       0.000000            0.000000 -9.223321e+18
# 25%                       0.000000            0.200000 -4.630740e+18
# 50%                       0.000000            0.400000  6.201597e+16
# 75%                       1.000000            0.600000  4.565156e+18
# max                       1.000000            1.000000  9.218903e+18
#
#          mission_id
# count  1.619389e+06
# mean  -1.240421e+17
# std    5.286050e+18
# min   -9.144214e+18
# 25%   -4.724245e+18
# 50%   -2.274875e+17
# 75%    3.909487e+18
# max    9.217426e+18

# %%
c=df.sort_index(axis=1,ascending=False)
c.to_csv('work3.csv',index=False)

# %%
d=df2.sort_index(axis=1,ascending=False)
d.head(10000).to_excel('work4.xlsx')

# %%
e=df["grade"]
print(e)
e.to_csv('work5.csv',index=False)
# Out:
# 0          5
# 1          5
# 2          6
# 3          5
# 4          6
#           ..
# 1619385    4
# 1619386    5
# 1619387    5
# 1619388    5
# 1619389    5
# Name: grade, Length: 1619390, dtype: int64

# %%
f=df[0:3]
print(f)
f.to_csv('work5.csv',index=False)
# Out:
#    grade                mission_name mission_difficulty mission_field  \
# 0      5  05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5   05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6   05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                  112.0            112-2
# 1           連續                  112.0            112-2
# 2           連續                  112.0            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1  Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 2  Thu May 09 08:00:00 UTC 2024          已派發任務           0.0  ...
#
#   answer_duration_sec  mission_answer_count  content_indicator_correct_rate  \
# 0                 NaN                   0.0                             NaN
# 1                 NaN                   0.0                             NaN
# 2                 NaN                   0.0                             NaN
#
#    comprehensive_indicator_correct_rate  explanation_indicator_correct_rate  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
#
#    extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
#
#    first_correct_rate       user_id    mission_id
# 0                 NaN -8.373966e+18  8.154604e+18
# 1                 NaN  3.516684e+18  3.762301e+18
# 2                 NaN -6.579905e+16  4.652808e+18
#
# [3 rows x 22 columns]

# %%
g=df["grade"][0:3]
print(g)
g.to_excel('work6.xlsx')
# Out:
# 0    5
# 1    5
# 2    6
# Name: grade, dtype: int64

# %%
a='grade'
df2.duplicated(subset=[a]).sum()
# Out:
# 1619384

# %%
duplication = df2[df2.duplicated(a)]
duplication[a]
# Out:
# 1          5
# 3          5
# 4          6
# 5          6
# 6          5
#           ..
# 1619385    4
# 1619386    5
# 1619387    5
# 1619388    5
# 1619389    5
# Name: grade, Length: 1619384, dtype: int64

# %%
a = 'user_id'
df3 = df2.drop_duplicates(a)
df3
# Out:
#          grade                        mission_name mission_difficulty  \
# 0            5          05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5           05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6           05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5          05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6    05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                                 ...                ...
# 1024468      4       01/15 關於跳躍力的祕密【生命教育－運動鍛鍊】(初階)                  易
# 1140603      7  01/15 VR把你放進別人的鞋裡？！【科技教育－現代科技】(中階)                  中
# 1167646      4              06/27 紙【能源教育－環境保育】（初階）                  易
# 1460810      7  01/15 VR把你放進別人的鞋裡？！【科技教育－現代科技】(中階)                  中
# 1619389      5                              04/25                 NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 0                  文學           連續                  112.0            112-2
# 1                  文學           連續                  112.0            112-2
# 2                  人物           連續                  112.0            112-2
# 3                生活知識          非連續                  112.0            112-2
# 4                自然科學        連續＋圖表                  112.0            112-2
# ...               ...          ...                    ...              ...
# 1024468          生活知識           連續                  112.0            112-1
# 1140603            議題           連續                  112.0            112-1
# 1167646          生活知識        連續＋圖表                  112.0            112-2
# 1460810            議題           連續                  112.0            112-1
# 1619389           NaN          NaN                    NaN              NaN
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 0        Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1        Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 2        Thu May 09 08:00:00 UTC 2024          已派發任務           0.0  ...
# 3        Mon May 13 08:00:00 UTC 2024          已派發任務           0.0  ...
# 4        Thu May 16 08:00:00 UTC 2024          已派發任務           0.0  ...
# ...                               ...            ...           ...  ...
# 1024468  Mon Jan 15 08:00:00 UTC 2024          進行任務中           0.0  ...
# 1140603  Mon Jan 15 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1167646  Thu Jun 27 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1460810  Mon Jan 15 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619389                           NaN            NaN           NaN  ...
#
#         answer_duration_sec  mission_answer_count  \
# 0                       NaN                   0.0
# 1                       NaN                   0.0
# 2                       NaN                   0.0
# 3                       NaN                   0.0
# 4                       NaN                   0.0
# ...                     ...                   ...
# 1024468                 NaN                   2.0
# 1140603                 NaN                   0.0
# 1167646                 NaN                   0.0
# 1460810                 NaN                   0.0
# 1619389                 NaN                   NaN
#
#          content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ...                                 ...                                   ...
# 1024468                             NaN                                   NaN
# 1140603                             NaN                                   NaN
# 1167646                             NaN                                   NaN
# 1460810                             NaN                                   NaN
# 1619389                             NaN                                   NaN
#
#          explanation_indicator_correct_rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1024468                                 NaN
# 1140603                                 NaN
# 1167646                                 NaN
# 1460810                                 NaN
# 1619389                                 NaN
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 1024468                                NaN                          NaN
# 1140603                                NaN                          NaN
# 1167646                                NaN                          NaN
# 1460810                                NaN                          NaN
# 1619389                                NaN                          NaN
#
#          first_correct_rate       user_id    mission_id
# 0                       NaN -8.373966e+18  8.154604e+18
# 1                       NaN  3.516684e+18  3.762301e+18
# 2                       NaN -6.579905e+16  4.652808e+18
# 3                       NaN -6.293485e+18  2.406214e+17
# 4                       NaN  4.998280e+18 -3.340858e+18
# ...                     ...           ...           ...
# 1024468                 0.6 -2.434296e+18  4.447409e+18
# 1140603                 NaN -2.023147e+18  6.244253e+18
# 1167646                 NaN -3.850367e+18  6.001971e+18
# 1460810                 NaN  4.004540e+18  6.244253e+18
# 1619389                 NaN           NaN           NaN
#
# [11608 rows x 22 columns]

# %%
p='one two one two one two'.split()
p1='a1 a2 a3 a4 a5 a6'.split()
df3=pd.DataFrame(
    {
        "A":p,
        "B":p1,
        "C":np.random.randn(6),
        "D":np.random.randn(6),
    }
)
df3
# Out:
#      A   B         C         D
# 0  one  a1 -0.082450  0.811607
# 1  two  a2  0.081957 -1.116439
# 2  one  a3  1.151600 -1.184013
# 3  two  a4  0.685641  0.510289
# 4  one  a5  1.655471  1.320172
# 5  two  a6  1.897889  1.506445

# %%
df3.groupby("A").sum()
# Out:
#           B         C         D
# A
# one  a1a3a5  0.113209  0.235279
# two  a2a4a6 -0.164208  1.183318

# %%
h=df2.columns
pp2=[]
for i in h:
  try:
    print(df2[i].groupby(df2[i]).count())
    pp2.append(df2[i].groupby(df2[i]).count())
  except:
    print('KeyError')
# Out:
# grade
# 4    378849
# 5    388624
# 6    349413
# 7    201454
# 8    162654
# 9    138396
# Name: grade, dtype: int64
# mission_name
# 01/01 我們是用戶還是商品？社群媒體之戰【資訊教育－社群媒體】(中階)     3056
# 01/01 數據風暴【資訊教育－社群媒體】(中階)                 2992
# 01/01 表情符號【資訊教育－資訊解讀】(初階)                 6727
# 01/01 觀影資訊【資訊教育－資訊解讀】(初階)                 6698
# 01/04 你可能已經犯罪了！【資訊教育－數位倫理】(中階)            3042
#                                          ...
# 5月特別任務－【SDGs 議題】（初階）                      6453
# 6月特別任務－【SDGs 議題】（中階）                      3240
# 6月特別任務－【SDGs 議題】（初階）                      6482
# 9月特別任務－【SDGs 議題】（中階）                      8640
# 9月特別任務－【SDGs 議題】（初階）                     19968
# Name: mission_name, Length: 336, dtype: int64
# mission_difficulty
# 中    873549
# 易    417003
# 難    252374
# Name: mission_difficulty, dtype: int64
# mission_field
# 世界櫥窗    169212
# 人文史地    140626
# 人物       67438
# 文化      128241
# 文學       67548
# 生活知識    388765
# 社會科學     81328
# 自然科學    182337
# 說明文件     68888
# 議題      248543
# Name: mission_field, dtype: int64
# mission_type
# 連續       877535
# 連續＋圖表    194885
# 非連續      470506
# Name: mission_type, dtype: int64
# mission_semester_year
# 112.0    1619389
# Name: mission_semester_year, dtype: int64
# mission_semester
# 112-1    830367
# 112-2    789022
# Name: mission_semester, dtype: int64
# mission_datetime_utc8
# Fri Dec 22 08:00:00 UTC 2023     9665
# Fri Mar 22 08:00:00 UTC 2024     9342
# Fri Sep 22 08:00:00 UTC 2023    28608
# Mon Apr 01 08:00:00 UTC 2024    18735
# Mon Apr 08 08:00:00 UTC 2024    18562
#                                 ...
# Thu Sep 14 08:00:00 UTC 2023    19073
# Thu Sep 21 08:00:00 UTC 2023    19127
# Thu Sep 28 08:00:00 UTC 2023    19180
# Wed May 22 08:00:00 UTC 2024     9653
# Wed Nov 22 08:00:00 UTC 2023     9708
# Name: mission_datetime_utc8, Length: 86, dtype: int64
# mission_status
# 取消派發        2719
# 完成任務      395897
# 已派發任務    1180814
# 暫停任務       34490
# 進行任務中       5469
# Name: mission_status, dtype: int64
# is_completed
# 0.0    1222568
# 1.0     396821
# Name: is_completed, dtype: int64
# completed_at_utc8
# Fri Apr 05 07:44:10 UTC 2024    1
# Fri Apr 05 07:51:52 UTC 2024    1
# Fri Apr 05 07:52:32 UTC 2024    1
# Fri Apr 05 07:53:22 UTC 2024    1
# Fri Apr 05 07:55:32 UTC 2024    1
#                                ..
# Wed Sep 27 22:47:44 UTC 2023    1
# Wed Sep 27 22:50:10 UTC 2023    1
# Wed Sep 27 23:01:33 UTC 2023    1
# Wed Sep 27 23:11:05 UTC 2023    1
# Wed Sep 27 23:20:47 UTC 2023    1
# Name: completed_at_utc8, Length: 343469, dtype: int64
# correct_rate
# 0.000000    70843
# 0.066667     1375
# 0.133333     2405
# 0.166667        2
# 0.200000    93884
# 0.266667     3560
# 0.300000        1
# 0.333333     2684
# 0.400000    82707
# 0.466667     1039
# 0.500000        1
# 0.533333      618
# 0.600000    53416
# 0.666667      259
# 0.733333      216
# 0.800000    37817
# 0.866667      164
# 0.933333      123
# 1.000000    45707
# Name: correct_rate, dtype: int64
# answer_duration_sec
# 1.0         322
# 2.0         914
# 3.0        3743
# 4.0        9272
# 5.0       14352
#           ...
# 3556.0        1
# 3585.0        1
# 3598.0        1
# 3599.0       35
# 3600.0     2030
# Name: answer_duration_sec, Length: 2210, dtype: int64
# mission_answer_count
# 0.0      1195016
# 1.0        92480
# 2.0       164709
# 3.0        76834
# 4.0        36715
#           ...
# 74.0           1
# 90.0           1
# 94.0           1
# 117.0          1
# 210.0          1
# Name: mission_answer_count, Length: 67, dtype: int64
# content_indicator_correct_rate
# 0.0    55253
# 0.5     3247
# 1.0    32917
# Name: content_indicator_correct_rate, dtype: int64
# comprehensive_indicator_correct_rate
# 0.000000    155238
# 0.111111       891
# 0.125000       530
# 0.142857      1282
# 0.166667       175
# 0.200000      1047
# 0.222222      1104
# 0.250000      6855
# 0.285714      1331
# 0.333333     34517
# 0.375000       390
# 0.400000       760
# 0.428571       851
# 0.444444       541
# 0.500000     61133
# 0.555556       275
# 0.571429       404
# 0.600000       320
# 0.625000        90
# 0.666667     22283
# 0.714286       186
# 0.750000      2995
# 0.777778       116
# 0.800000       106
# 0.833333        14
# 0.857143       117
# 0.875000        34
# 0.888889        81
# 1.000000     97990
# Name: comprehensive_indicator_correct_rate, dtype: int64
# explanation_indicator_correct_rate
# 0.000000    183031
# 0.166667       941
# 0.200000       155
# 0.250000       722
# 0.333333      6276
# 0.400000       139
# 0.500000     41610
# 0.600000        90
# 0.666667      3278
# 0.750000       115
# 0.800000        59
# 0.833333        45
# 1.000000    106265
# Name: explanation_indicator_correct_rate, dtype: int64
# extraction_indicator_correct_rate
# 0.000000    171475
# 0.166667       513
# 0.200000      2539
# 0.250000      1686
# 0.333333      6074
# 0.400000      1847
# 0.500000     42118
# 0.600000       820
# 0.666667      3332
# 0.750000       383
# 0.800000       359
# 0.833333        58
# 1.000000    130361
# Name: extraction_indicator_correct_rate, dtype: int64
# form_indicator_correct_rate
# 0.0    43075
# 0.5      586
# 1.0    25751
# Name: form_indicator_correct_rate, dtype: int64
# first_correct_rate
# 0.000000     51955
# 0.066667       837
# 0.133333      1930
# 0.200000    100589
# 0.266667      3216
# 0.333333      2500
# 0.400000     90004
# 0.466667       993
# 0.500000         1
# 0.533333       599
# 0.600000     58652
# 0.666667       258
# 0.700000         1
# 0.733333       215
# 0.800000     44548
# 0.866667       163
# 0.933333       121
# 1.000000     56234
# Name: first_correct_rate, dtype: int64
# user_id
# -9.223321e+18    159
# -9.222609e+18     77
# -9.221920e+18    120
# -9.221135e+18    155
# -9.221071e+18    151
#                 ...
#  9.212461e+18    103
#  9.212946e+18    149
#  9.215839e+18     73
#  9.216205e+18    148
#  9.218903e+18    134
# Name: user_id, Length: 11607, dtype: int64
# mission_id
# -9.144214e+18    2719
# -9.108400e+18    6431
# -9.027191e+18    6747
# -9.015410e+18    3056
# -8.952441e+18    2952
#                  ...
#  9.100905e+18    6697
#  9.118853e+18    6459
#  9.122208e+18    2872
#  9.180295e+18    6418
#  9.217426e+18    6749
# Name: mission_id, Length: 339, dtype: int64

# %%
with open('次數table_3.txt','w',encoding='utf-8') as f:
  f.write(str(pp2))
  f.close

# %%
df2.dropna()
# Out:
#          grade               mission_name mission_difficulty mission_field  \
# 677          6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 1333         4  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 4975         5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 4976         5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 4977         5  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# ...        ...                        ...                ...           ...
# 1617441      6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 1617447      6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 1617448      6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 1617452      6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
# 1617455      6  11/16 環保吸管【環境教育－環境保護】(初階)                  中          生活知識
#
#         mission_type  mission_semester_year mission_semester  \
# 677               連續                  112.0            112-1
# 1333              連續                  112.0            112-1
# 4975              連續                  112.0            112-1
# 4976              連續                  112.0            112-1
# 4977              連續                  112.0            112-1
# ...              ...                    ...              ...
# 1617441           連續                  112.0            112-1
# 1617447           連續                  112.0            112-1
# 1617448           連續                  112.0            112-1
# 1617452           連續                  112.0            112-1
# 1617455           連續                  112.0            112-1
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 677      Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 1333     Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 4975     Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 4976     Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 4977     Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# ...                               ...            ...           ...  ...
# 1617441  Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 1617447  Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 1617448  Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 1617452  Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
# 1617455  Thu Nov 16 08:00:00 UTC 2023           完成任務           1.0  ...
#
#         answer_duration_sec  mission_answer_count  \
# 677                     8.0                   2.0
# 1333                   49.0                   4.0
# 4975                    5.0                   2.0
# 4976                   15.0                   1.0
# 4977                    3.0                   3.0
# ...                     ...                   ...
# 1617441               114.0                   2.0
# 1617447                17.0                   1.0
# 1617448                46.0                   3.0
# 1617452               485.0                   1.0
# 1617455               249.0                   1.0
#
#          content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 677                                 1.0                                   0.0
# 1333                                0.0                                   0.0
# 4975                                0.0                                   1.0
# 4976                                1.0                                   1.0
# 4977                                0.0                                   0.0
# ...                                 ...                                   ...
# 1617441                             0.0                                   1.0
# 1617447                             1.0                                   1.0
# 1617448                             0.0                                   1.0
# 1617452                             1.0                                   1.0
# 1617455                             1.0                                   1.0
#
#          explanation_indicator_correct_rate  \
# 677                                     0.0
# 1333                                    1.0
# 4975                                    0.0
# 4976                                    1.0
# 4977                                    0.0
# ...                                     ...
# 1617441                                 1.0
# 1617447                                 1.0
# 1617448                                 0.0
# 1617452                                 1.0
# 1617455                                 1.0
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 677                                    1.0                          1.0
# 1333                                   1.0                          0.0
# 4975                                   1.0                          0.0
# 4976                                   1.0                          1.0
# 4977                                   0.0                          0.0
# ...                                    ...                          ...
# 1617441                                1.0                          1.0
# 1617447                                1.0                          1.0
# 1617448                                0.0                          0.0
# 1617452                                1.0                          1.0
# 1617455                                1.0                          1.0
#
#          first_correct_rate       user_id    mission_id
# 677                     0.6  4.524907e+18 -3.755334e+18
# 1333                    0.4  3.879789e+18 -3.755334e+18
# 4975                    0.4 -3.519350e+18 -3.755334e+18
# 4976                    1.0  8.189607e+18 -3.755334e+18
# 4977                    0.8 -1.625213e+18 -3.755334e+18
# ...                     ...           ...           ...
# 1617441                 0.8  5.917308e+18 -3.755334e+18
# 1617447                 1.0 -2.126249e+18 -3.755334e+18
# 1617448                 0.2 -5.972088e+18 -3.755334e+18
# 1617452                 1.0 -7.814697e+18 -3.755334e+18
# 1617455                 1.0  3.805847e+17 -3.755334e+18
#
# [1694 rows x 22 columns]

# %%
df2.fillna(5)
# Out:
#          grade                          mission_name mission_difficulty  \
# 0            5            05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5             05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6             05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5            05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6      05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                                   ...                ...
# 1619385      4  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619386      5             04/25 扭蛋【多元文化教育－日本文化】（初階）                  中
# 1619387      5  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619388      5  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619389      5                                04/25                   5
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 0                  文學           連續                  112.0            112-2
# 1                  文學           連續                  112.0            112-2
# 2                  人物           連續                  112.0            112-2
# 3                生活知識          非連續                  112.0            112-2
# 4                自然科學        連續＋圖表                  112.0            112-2
# ...               ...          ...                    ...              ...
# 1619385            文化           連續                  112.0            112-2
# 1619386          世界櫥窗           連續                  112.0            112-2
# 1619387            文化           連續                  112.0            112-2
# 1619388            文化           連續                  112.0            112-2
# 1619389             5            5                    5.0                5
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 0        Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1        Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 2        Thu May 09 08:00:00 UTC 2024          已派發任務           0.0  ...
# 3        Mon May 13 08:00:00 UTC 2024          已派發任務           0.0  ...
# 4        Thu May 16 08:00:00 UTC 2024          已派發任務           0.0  ...
# ...                               ...            ...           ...  ...
# 1619385  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619386  Thu Apr 25 08:00:00 UTC 2024           完成任務           1.0  ...
# 1619387  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619388  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619389                             5              5           5.0  ...
#
#         answer_duration_sec  mission_answer_count  \
# 0                       5.0                   0.0
# 1                       5.0                   0.0
# 2                       5.0                   0.0
# 3                       5.0                   0.0
# 4                       5.0                   0.0
# ...                     ...                   ...
# 1619385                 5.0                   0.0
# 1619386                24.0                   1.0
# 1619387                 5.0                   0.0
# 1619388                 5.0                   0.0
# 1619389                 5.0                   5.0
#
#          content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                   5.0                                   5.0
# 1                                   5.0                                   5.0
# 2                                   5.0                                   5.0
# 3                                   5.0                                   5.0
# 4                                   5.0                                   5.0
# ...                                 ...                                   ...
# 1619385                             5.0                                   5.0
# 1619386                             5.0                                   1.0
# 1619387                             5.0                                   5.0
# 1619388                             5.0                                   5.0
# 1619389                             5.0                                   5.0
#
#          explanation_indicator_correct_rate  \
# 0                                       5.0
# 1                                       5.0
# 2                                       5.0
# 3                                       5.0
# 4                                       5.0
# ...                                     ...
# 1619385                                 5.0
# 1619386                                 1.0
# 1619387                                 5.0
# 1619388                                 5.0
# 1619389                                 5.0
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                      5.0                          5.0
# 1                                      5.0                          5.0
# 2                                      5.0                          5.0
# 3                                      5.0                          5.0
# 4                                      5.0                          5.0
# ...                                    ...                          ...
# 1619385                                5.0                          5.0
# 1619386                                1.0                          5.0
# 1619387                                5.0                          5.0
# 1619388                                5.0                          5.0
# 1619389                                5.0                          5.0
#
#          first_correct_rate       user_id    mission_id
# 0                       5.0 -8.373966e+18  8.154604e+18
# 1                       5.0  3.516684e+18  3.762301e+18
# 2                       5.0 -6.579905e+16  4.652808e+18
# 3                       5.0 -6.293485e+18  2.406214e+17
# 4                       5.0  4.998280e+18 -3.340858e+18
# ...                     ...           ...           ...
# 1619385                 5.0 -7.530624e+18  1.877827e+18
# 1619386                 1.0  6.601996e+18  2.576055e+18
# 1619387                 5.0 -3.990416e+17  1.877827e+18
# 1619388                 5.0 -6.914625e+18  1.877827e+18
# 1619389                 5.0  5.000000e+00  5.000000e+00
#
# [1619390 rows x 22 columns]

# %%
df2.ffill()
# Out:
#          grade                          mission_name mission_difficulty  \
# 0            5            05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5             05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6             05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5            05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6      05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                                   ...                ...
# 1619385      4  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619386      5             04/25 扭蛋【多元文化教育－日本文化】（初階）                  中
# 1619387      5  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619388      5  04/25 日本印章文化——契機與革新【多元文化教育－日本文化】（初階）                  難
# 1619389      5                                04/25                   難
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 0                  文學           連續                  112.0            112-2
# 1                  文學           連續                  112.0            112-2
# 2                  人物           連續                  112.0            112-2
# 3                生活知識          非連續                  112.0            112-2
# 4                自然科學        連續＋圖表                  112.0            112-2
# ...               ...          ...                    ...              ...
# 1619385            文化           連續                  112.0            112-2
# 1619386          世界櫥窗           連續                  112.0            112-2
# 1619387            文化           連續                  112.0            112-2
# 1619388            文化           連續                  112.0            112-2
# 1619389            文化           連續                  112.0            112-2
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 0        Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1        Mon May 06 08:00:00 UTC 2024          已派發任務           0.0  ...
# 2        Thu May 09 08:00:00 UTC 2024          已派發任務           0.0  ...
# 3        Mon May 13 08:00:00 UTC 2024          已派發任務           0.0  ...
# 4        Thu May 16 08:00:00 UTC 2024          已派發任務           0.0  ...
# ...                               ...            ...           ...  ...
# 1619385  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619386  Thu Apr 25 08:00:00 UTC 2024           完成任務           1.0  ...
# 1619387  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619388  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
# 1619389  Thu Apr 25 08:00:00 UTC 2024          已派發任務           0.0  ...
#
#         answer_duration_sec  mission_answer_count  \
# 0                       NaN                   0.0
# 1                       NaN                   0.0
# 2                       NaN                   0.0
# 3                       NaN                   0.0
# 4                       NaN                   0.0
# ...                     ...                   ...
# 1619385                 5.0                   0.0
# 1619386                24.0                   1.0
# 1619387                24.0                   0.0
# 1619388                24.0                   0.0
# 1619389                24.0                   0.0
#
#          content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ...                                 ...                                   ...
# 1619385                             1.0                                   0.0
# 1619386                             1.0                                   1.0
# 1619387                             1.0                                   1.0
# 1619388                             1.0                                   1.0
# 1619389                             1.0                                   1.0
#
#          explanation_indicator_correct_rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1619385                                 0.0
# 1619386                                 1.0
# 1619387                                 1.0
# 1619388                                 1.0
# 1619389                                 1.0
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 1619385                                0.0                          1.0
# 1619386                                1.0                          1.0
# 1619387                                1.0                          1.0
# 1619388                                1.0                          1.0
# 1619389                                1.0                          1.0
#
#          first_correct_rate       user_id    mission_id
# 0                       NaN -8.373966e+18  8.154604e+18
# 1                       NaN  3.516684e+18  3.762301e+18
# 2                       NaN -6.579905e+16  4.652808e+18
# 3                       NaN -6.293485e+18  2.406214e+17
# 4                       NaN  4.998280e+18 -3.340858e+18
# ...                     ...           ...           ...
# 1619385                 1.0 -7.530624e+18  1.877827e+18
# 1619386                 1.0  6.601996e+18  2.576055e+18
# 1619387                 1.0 -3.990416e+17  1.877827e+18
# 1619388                 1.0 -6.914625e+18  1.877827e+18
# 1619389                 1.0 -6.914625e+18  1.877827e+18
#
# [1619390 rows x 22 columns]

# %%
df1 = pd.DataFrame(
  {
  "A": ["A0", "A1", "A2", "A3"],"B": ["B0", "B1", "B2", "B3"], "C": ["C0", "C1", "C2", "C3"], "D": ["D0", "D1", "D2", "D3"],
  },
  index=[0, 1, 2, 3],
  )
df2 = pd.DataFrame(
  {
  "A": ["A4", "A5", "A6", "A7"], "B": ["B4", "B5", "B6", "B7"], "C": ["C4", "C5", "C6", "C7"], "D": ["D4", "D5", "D6", "D7"],
  },
  index=[4, 5, 6, 7],
  )
df3 = pd.DataFrame(
  {
  "A": ["A8", "A9", "A10", "A11"], "B": ["B8", "B9", "B10", "B11"], "C": ["C8", "C9", "C10", "C11"], "D": ["D8", "D9", "D10", "D11"],
  },
  index=[8, 9, 10, 11],)
frames=[df1,df2,df3]
result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame(
{
"B": ["B2", "B3", "B6", "B7"],
"D": ["D2", "D3", "D6", "D7"],
"F": ["F2", "F3", "F6", "F7"],
},
index=[2, 3, 6, 7],
)
result = pd.concat([df1, df4], axis=1)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df4], axis=1).reindex(df1.index)
result
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %%
left = pd.DataFrame({"key": ["A","B"], "lval": [1,2]})
print(left)
right = pd.DataFrame({"key": ["A","B"], "rval": [3,4]})
print(right)
# according to the condition of key to merge
pd.merge(right, left, on="key")
# Out:
#   key  lval
# 0   A     1
# 1   B     2
#   key  rval
# 0   A     3
# 1   B     4
#   key  rval  lval
# 0   A     3     1
# 1   B     4     2

# %% [markdown]
# Homework 請把以下創造的資料拼接到學習資料(A_stat_data_112.csv)

# %%
gf= []
ww = df['grade']
for i in range(len(ww)):
  i+= 1
  gf.append(i)
df4 = pd.DataFrame(gf)
df4
# Out:
#                0
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 1909954  1909955
# 1909955  1909956
# 1909956  1909957
# 1909957  1909958
# 1909958  1909959
#
# [1909959 rows x 1 columns]

# %% [markdown]
# 原資料(A_stat_data_112.csv)

# %%
df
# Out:
#          grade                      mission_name mission_difficulty  \
# 0            5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                               ...                ...
# 1909954      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909955      8       04/22 人與鼠的戰爭【環境教育－動物保育】（中階）                  易
# 1909956      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909957      8              4月特別任務－【SDGs 議題】（中階）                NaN
# 1909958      9              4月特別任務－【SDGs 議題】（中階）                NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 0                  文學           連續                    112            112-2
# 1                  文學           連續                    112            112-2
# 2                  人物           連續                    112            112-2
# 3                生活知識          非連續                    112            112-2
# 4                自然科學        連續＋圖表                    112            112-2
# ...               ...          ...                    ...              ...
# 1909954            議題          非連續                    112            112-2
# 1909955          世界櫥窗           連續                    112            112-2
# 1909956            議題          非連續                    112            112-2
# 1909957           NaN          NaN                    112            112-2
# 1909958           NaN          NaN                    112            112-2
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 0        Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1        Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2        Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3        Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4        Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
# ...                               ...            ...           ...  ...
# 1909954  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909955  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909956  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909957  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909958  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
#
#         answer_duration_sec  mission_answer_count  \
# 0                       NaN                     0
# 1                       NaN                     0
# 2                       NaN                     0
# 3                       NaN                     0
# 4                       NaN                     0
# ...                     ...                   ...
# 1909954                 NaN                     0
# 1909955                 NaN                     0
# 1909956                 NaN                     0
# 1909957                 NaN                     0
# 1909958                 NaN                     0
#
#          content_indicator_correct_rate  comprehensive_indicator_correct_rate  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ...                                 ...                                   ...
# 1909954                             NaN                                   NaN
# 1909955                             NaN                                   NaN
# 1909956                             NaN                                   NaN
# 1909957                             NaN                                   NaN
# 1909958                             NaN                                   NaN
#
#          explanation_indicator_correct_rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1909954                                 NaN
# 1909955                                 NaN
# 1909956                                 NaN
# 1909957                                 NaN
# 1909958                                 NaN
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 1909954                                NaN                          NaN
# 1909955                                NaN                          NaN
# 1909956                                NaN                          NaN
# 1909957                                NaN                          NaN
# 1909958                                NaN                          NaN
#
#          first_correct_rate              user_id           mission_id
# 0                       NaN -8373966078912715601  8154604467375388289
# 1                       NaN  3516683932418412104  3762301478342295221
# 2                       NaN   -65799051578279613  4652807748946159405
# 3                       NaN -6293485111595748020   240621445882253268
# 4                       NaN  4998280410504838977 -3340858198738005072
# ...                     ...                  ...                  ...
# 1909954                 NaN  5090607127449525741   703618323232836566
# 1909955                 NaN  1122720388891184818  8809938774431070893
# 1909956                 NaN -3633088233029289359   703618323232836566
# 1909957                 NaN -3198336096824660439  -371611706378504607
# 1909958                 NaN  8248998181802054321  -371611706378504607
#
# [1909959 rows x 22 columns]

# %% [markdown]
# 拼接到result並輸出csv檔

# %%
result = pd.concat([df, df4], axis=1)
result.to_csv('result.csv',index=False)

# %%
result
# Out:
#          grade                      mission_name mission_difficulty  \
# 0            5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                               ...                ...
# 1909954      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909955      8       04/22 人與鼠的戰爭【環境教育－動物保育】（中階）                  易
# 1909956      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909957      8              4月特別任務－【SDGs 議題】（中階）                NaN
# 1909958      9              4月特別任務－【SDGs 議題】（中階）                NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 0                  文學           連續                    112            112-2
# 1                  文學           連續                    112            112-2
# 2                  人物           連續                    112            112-2
# 3                生活知識          非連續                    112            112-2
# 4                自然科學        連續＋圖表                    112            112-2
# ...               ...          ...                    ...              ...
# 1909954            議題          非連續                    112            112-2
# 1909955          世界櫥窗           連續                    112            112-2
# 1909956            議題          非連續                    112            112-2
# 1909957           NaN          NaN                    112            112-2
# 1909958           NaN          NaN                    112            112-2
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# 0        Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 1        Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# 2        Thu May 09 08:00:00 UTC 2024          已派發任務             0  ...
# 3        Mon May 13 08:00:00 UTC 2024          已派發任務             0  ...
# 4        Thu May 16 08:00:00 UTC 2024          已派發任務             0  ...
# ...                               ...            ...           ...  ...
# 1909954  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909955  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909956  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909957  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
# 1909958  Mon Apr 22 08:00:00 UTC 2024          已派發任務             0  ...
#
#         mission_answer_count  content_indicator_correct_rate  \
# 0                          0                             NaN
# 1                          0                             NaN
# 2                          0                             NaN
# 3                          0                             NaN
# 4                          0                             NaN
# ...                      ...                             ...
# 1909954                    0                             NaN
# 1909955                    0                             NaN
# 1909956                    0                             NaN
# 1909957                    0                             NaN
# 1909958                    0                             NaN
#
#          comprehensive_indicator_correct_rate  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1909954                                   NaN
# 1909955                                   NaN
# 1909956                                   NaN
# 1909957                                   NaN
# 1909958                                   NaN
#
#          explanation_indicator_correct_rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1909954                                 NaN
# 1909955                                 NaN
# 1909956                                 NaN
# 1909957                                 NaN
# 1909958                                 NaN
#
#          extraction_indicator_correct_rate  form_indicator_correct_rate  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 1909954                                NaN                          NaN
# 1909955                                NaN                          NaN
# 1909956                                NaN                          NaN
# 1909957                                NaN                          NaN
# 1909958                                NaN                          NaN
#
#          first_correct_rate              user_id           mission_id        0
# 0                       NaN -8373966078912715601  8154604467375388289        1
# 1                       NaN  3516683932418412104  3762301478342295221        2
# 2                       NaN   -65799051578279613  4652807748946159405        3
# 3                       NaN -6293485111595748020   240621445882253268        4
# 4                       NaN  4998280410504838977 -3340858198738005072        5
# ...                     ...                  ...                  ...      ...
# 1909954                 NaN  5090607127449525741   703618323232836566  1909955
# 1909955                 NaN  1122720388891184818  8809938774431070893  1909956
# 1909956                 NaN -3633088233029289359   703618323232836566  1909957
# 1909957                 NaN -3198336096824660439  -371611706378504607  1909958
# 1909958                 NaN  8248998181802054321  -371611706378504607  1909959
#
# [1909959 rows x 23 columns]
